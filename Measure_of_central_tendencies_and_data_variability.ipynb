# %% [markdown]
# <a href="https://colab.research.google.com/github/MJanbandhu/statistics-/blob/main/Measure_of_central_tendencies_and_data_variability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # Visualization
# %matplotlib inline

# %%
## generating a random variable
exp=np.random.normal(25000,15000,1000) #mean,standard deviation, number of datapoints

# %%
exp
# Out:
# array([  9670.11551951,  -1199.53873995,  34050.60762005,  28405.9289316 ,
#         41746.54211371,  29065.16276108,  35202.73981431,  25435.35225742,
#         34318.61865419,  38362.42645918,  22699.64774258,  23224.68958887,
#         48623.47483951,  15875.91810886,  39204.4771129 ,  12438.61819248,
#         17339.92433331,   3642.24928064,  54376.36869242,  38708.8608414 ,
#          7326.57581602,  44014.59526363,  50170.29401703,  31112.70640812,
#         39932.03945201,  26441.66927528,  19086.95695004,  30868.28234525,
#        -15445.19925694,  17379.10910994,   3428.2677578 ,  40646.7293765 ,
#          8305.09014583,  12976.94771402,  35518.01446976,  29702.17557555,
#          5816.90945183,   3930.61407018,  38421.99108863,  16532.5463832 ,
#         38081.61170185,  33820.30313089,  17341.34156941,  28278.82472632,
#         28188.20749556,  30653.86811771,  16623.2444585 ,  17198.43474099,
# ...

# %%
## plotting the randomly generated exp
pd.DataFrame(exp).plot(kind='hist')
plt.show()

# %%
import seaborn as sns
sns.kdeplot(exp)
# Out:
# <Axes: ylabel='Density'>

# %%
## calculating mean before adding outlier
np.mean(exp)
# Out:
# 26270.18937831336

# %%
## calculating median before adding outlier
np.median(exp)
# Out:
# 26712.94368384713

# %%
## adding one huge point,outlier
exp=np.append(exp,[100000000])

# %%
sns.kdeplot(exp)
# Out:
# <Axes: ylabel='Density'>

# %%
#Mean after outlier
np.mean(exp)
# Out:
# 126144.04533298037

# %%
#Median after outlier
np.median(exp)
# Out:
# 26715.861085234894

# %%
## mode
exp=np.random.randint(15,high=50,size=200) # Generates 200 random integers between 15-50

# %%
exp
# Out:
# array([22, 25, 37, 29, 31, 44, 19, 26, 19, 29, 42, 15, 16, 44, 44, 37, 17,
#        30, 18, 18, 33, 22, 21, 18, 32, 22, 43, 23, 44, 38, 16, 49, 31, 32,
#        40, 31, 33, 23, 32, 36, 18, 41, 49, 37, 25, 20, 46, 48, 45, 42, 16,
#        15, 32, 26, 41, 46, 35, 38, 38, 20, 38, 26, 47, 49, 45, 44, 48, 28,
#        35, 17, 45, 36, 46, 30, 45, 48, 43, 17, 46, 33, 15, 38, 25, 39, 39,
#        32, 27, 37, 15, 40, 21, 18, 44, 29, 32, 35, 47, 36, 42, 30, 48, 48,
#        45, 17, 31, 19, 41, 33, 24, 22, 43, 18, 47, 23, 18, 37, 24, 39, 16,
#        33, 42, 36, 29, 39, 25, 30, 40, 18, 37, 42, 35, 49, 43, 24, 49, 41,
#        20, 29, 41, 39, 44, 35, 28, 43, 36, 49, 40, 21, 22, 45, 34, 17, 47,
#        35, 29, 30, 39, 16, 36, 39, 25, 16, 36, 36, 17, 38, 46, 25, 18, 21,
#        39, 45, 43, 33, 40, 19, 42, 35, 44, 48, 44, 28, 31, 36, 31, 35, 22,
#        34, 35, 16, 27, 21, 48, 21, 39, 45, 19, 32, 18, 43])

# %%
sns.histplot(exp)
# Out:
# <Axes: ylabel='Count'>

# %%
from scipy import stats
stats.mode(exp)
# Out:
# C:\Users\AKCLAP-19\AppData\Local\Temp\ipykernel_14228\502054623.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(exp)
# ModeResult(mode=array([18]), count=array([10]))

# %%
## calculating IQR
data=[46,47,56,2,36,39,75,79,79,88,89,91,92,93,96,97,101,105,112,115]

# %%
IQR=stats.iqr(data,interpolation='midpoint')

# %%
IQR
# Out:
# 45.0

# %%
# median of data
np.median(data)
# Out:
# 88.5

# %%
# 50th Percentile
np.percentile(data,50)
# Out:
# 88.5

# %%
# Task: Find out Lower bound and Upper Bound of data

# %%
## variance and standard deviation
np.var(data)
# Out:
# 839.79

# %%
np.std(data)
# Out:
# 28.979130421736258

# %%
data=[46,47,56,2,36,39,75,79,79,88,89,91,92,93,96,97,101,105,112,115]
sns.boxplot(data, orient="h")
# Out:
# <Axes: >
